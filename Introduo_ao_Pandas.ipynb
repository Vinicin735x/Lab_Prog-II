# %% [markdown]
# # **Antes de resolver o exercícios, os alunos devem carregar os dados:**

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Baixar os dados do índice Bovespa (IBOV)
ibov_data = yf.download('^BVSP', start='2020-01-01', end='2025-01-10')
print(ibov_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open   Volume
# Ticker         ^BVSP     ^BVSP     ^BVSP     ^BVSP    ^BVSP
# Date
# 2020-01-02  118573.0  118573.0  115649.0  115652.0  5162700
# 2020-01-03  117707.0  118792.0  117341.0  118564.0  6834500
# 2020-01-06  116878.0  117707.0  116269.0  117707.0  6570000
# 2020-01-07  116662.0  117076.0  115965.0  116872.0  4854100
# 2020-01-08  116247.0  117335.0  115693.0  116667.0  5910500

# %% [markdown]
# 1 - Utilizando a série ibov_series, faça um gráfico simples que mostre a variação do valor de fechamento do índice Bovespa ao longo do tempo. Certifique-se de adicionar rótulos ao eixo X e ao eixo Y e um título ao gráfico.
#
# **Dica:** *Utilize o método* plot() *do Pandas*

# %%
ibove_series = ibov_data['Close'] #ibove_series recebe apenas a coluna close do ibov_data
ibove_series.plot(title="Variação do valor de fechamento do índice Bovespa ao longo do tempo", xlabel='Anos', ylabel='Valores', kind="line") 
# o plot é usado para criar gráficos
# Out:
# <Axes: title={'center': 'Variação do valor de fechamento do índice Bovespa ao longo do tempo'}, xlabel='Anos', ylabel='Valores'>

# %% [markdown]
# 2 - Usando a série ibov_series, calcule e exiba no console as seguintes estatísticas básicas: valor máximo, valor mínimo, média e mediana do índice Bovespa no período analisado.
#
# **Dicas**: *Utilize os métodos* max(), min(), mean() e median() *da série Pandas para calcular as estatísticas. Experimente exibir os resultados de forma clara e organizada.*

# %%
print(f"Maior valor: {ibove_series.max().values[0]}")
print(f"Menor valor: {ibove_series.min().values[0]}")
print(f"Média: {ibove_series.mean().values[0]}")
print(f"Mediana: {ibove_series.median().values[0]}")
# Out:
# Maior valor: 137344.0
# Menor valor: 63570.0
# Média: 113581.5528
# Mediana: 114718.5

# %% [markdown]
# # **Antes de resolver os exercícios, os alunos devem carregar os dados a partir do arquivo CSV:**
#
# Este dataset contém classificações e indicadores detalhados do Índice de Prosperidade Legatum de 2023, avaliando e classificando países com base em várias dimensões de prosperidade e desenvolvimento. Os indicadores abrangem aspectos como:
#
# * País: O nome do país.
# * Pontuação média: A pontuação média geral do país em todos os indicadores.
# * Segurança Segurança: Liberdade de conflito, terrorismo e crime.
# * Liberdade pessoal: Direitos de expressão, reunião e autonomia individual.
# * Governança: Qualidade da democracia, Estado de direito e eficácia do governo.
# * Capital social: Força dos relacionamentos pessoais e engajamento cívico.
# * Ambiente de investimento: Condições para investimento privado e acesso a crédito.
# * Condições empresariais: Ambiente de negócios e concorrência de mercado.
# * Acesso ao mercado Infraestrutura: Facilidade de comércio e qualidade da infraestrutura.
# * Qualidade econômica: Estabilidade macroeconômica e qualidade do emprego.
# * Condições de vida: Padrão de vida e acesso a serviços básicos.
# * Saúde: Saúde da população e acesso à assistência médica.
# * Educação: Qualidade e acessibilidade da educação.
# * Ambiente natural: Qualidade ambiental e sustentabilidade.

# %%
import pandas as pd

# Carregar os dados do arquivo CSV em um DataFrame
DF = pd.read_csv('data.csv')

# Exibir as primeiras linhas do DataFrame para ver a estrutura dos dados
DF.head()
# Out:
#          Country  AveragScore  SafetySecurity  PersonelFreedom  Governance  \
# 0        Denmark        84.55           92.59            94.09       89.45
# 1         Sweden        83.67           90.97            91.90       86.41
# 2         Norway        83.59           93.30            94.10       89.66
# 3        Finland        83.47           89.56            91.96       90.41
# 4    Switzerland        83.42           95.66            87.50       87.67
#
#    SocialCapital  InvestmentEnvironment  EnterpriseConditions  \
# 0          82.56                  82.42                 79.64
# 1          78.29                  82.81                 75.54
# 2          79.03                  82.24                 75.95
# 3          77.27                  84.12                 77.25
# 4          69.14                  80.81                 83.84
#
#    MarketAccessInfrastructure  EconomicQuality  LivingConditions  Health  \
# 0                       78.79            76.81             95.77   81.07
# 1                       79.67            76.18             95.33   82.28
# 2                       75.87            77.25             94.70   82.98
# 3                       78.77            70.28             94.46   81.19
# 4                       78.65            79.71             94.66   82.11
#
#    Education  NaturalEnvironment
# 0      87.48               73.94
# 1      85.92               78.74
# 2      85.68               72.37
# 3      88.38               77.99
# 4      87.72               73.60

# %% [markdown]
# 3 - Usando o DataFrame df, selecione e exiba todos os países que têm uma pontuação superior a 70 em "Educação" e uma pontuação superior a 75 em "Saúde". Mostre apenas as colunas "País", "Educação" e "Saúde" para esses países.
#
# **Dicas**:
# *Use a indexação com colchetes ([]) e operadores lógicos (&) para filtrar os dados.
# Lembre-se de utilizar o método loc ou [] para selecionar as colunas específicas.*

# %%
df_filtrado = DF[(DF["Education"]> 70) & (DF["Health"]> 75)]
print(df_filtrado[['Country', 'Education', 'Health']])
# Out:
#                    Country  Education  Health
# 0                  Denmark      87.48   81.07
# 1                   Sweden      85.92   82.28
# 2                   Norway      85.68   82.98
# 3                  Finland      88.38   81.19
# 4              Switzerland      87.72   82.11
# 5              Netherlands      86.43   82.05
# 6               Luxembourg      78.79   81.59
# 7                  Iceland      85.19   82.72
# 8                  Germany      83.45   81.41
# 9              New Zealand      83.89   79.84
# 10                 Ireland      85.00   80.04
# 11          United Kingdom      84.81   78.31
# 12                  Canada      84.19   78.88
# 13                 Austria      81.93   80.23
# 14               Australia      85.99   80.36
# 15                   Japan      84.93   86.50
# 16               Singapore      91.44   86.89
# 17                 Belgium      84.79   80.60
# 19                  Taiwan      84.61   83.37
# 20                 Estonia      82.19   77.71
# 21               Hong Kong      85.81   81.33
# 22                  France      81.27   80.46
# 23                   Spain      80.98   79.66
# 24          Czech Republic      80.66   79.49
# 25                Portugal      77.64   77.44
# 26                Slovenia      81.80   79.88
# 27                   Malta      78.33   80.54
# 28             South Korea      87.76   84.80
# 29                   Italy      80.00   80.90
# 32                  Israel      81.63   83.10
# 33                  Cyprus      79.14   79.23
# 34                Slovakia      72.75   76.74
# 35                   Chile      73.47   76.06
# 36                  Poland      78.63   76.31
# 37                 Uruguay      70.64   77.98
# 38              Costa Rica      71.71   79.09
# 39                  Greece      79.34   77.43
# 40                 Croatia      73.54   75.74
# 41                 Hungary      77.34   76.70
# 42                Malaysia      72.94   77.35
# 43    United Arab Emirates      74.72   78.38
# 53                   China      70.42   83.11
# 103                   Cuba      70.43   79.53

# %% [markdown]
# 4 - Apresente a matriz de correlação somente dos valores numéricos.

# %%
DF.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 DF.corr()
#
# NameError: name 'DF' is not defined

# %%
import pandas as pd
obj = pd.Series([4, 5, 2, -7], index = ['a', 'b', 'c', 'd'])
obj * 3
# Out:
# a    12
# b    15
# c     6
# d   -21
# dtype: int64

# %%
data = {"Estado": ['Minas Gerais', 'Minas Gerais', 'Minas Gerais', 'São Paulo', 'São Paulo', 'São Paulo' ], 
        'ano': [2000, 2001, 2005, 2000, 2001, 2005], 
        'pop': [1.7, 1.9, 2.0, 1.7, 1.9, 2.0]}
frame = pd.DataFrame(data, columns=['ano', 'Estado', 'pop'])
frame
# Out:
#     ano        Estado  pop
# 0  2000  Minas Gerais  1.7
# 1  2001  Minas Gerais  1.9
# 2  2005  Minas Gerais  2.0
# 3  2000     São Paulo  1.7
# 4  2001     São Paulo  1.9
# 5  2005     São Paulo  2.0

# %%
frame2 = pd.DataFrame(data, columns=['ano','estado', 'pop', 'dívida'],
                      index= ['Um', 'Dois', 'Três', 'Quatro', 'Cinco', 'Seis'])
frame2
# Out:
#         ano estado  pop dívida
# Um      NaN    NaN  NaN    NaN
# Dois    NaN    NaN  NaN    NaN
# Três    NaN    NaN  NaN    NaN
# Quatro  NaN    NaN  NaN    NaN
# Cinco   NaN    NaN  NaN    NaN
# Seis    NaN    NaN  NaN    NaN

# %%
data = (2, 4, 8, 10, 20)
series = pd.Series(data)
print(series.mean())
# Out:
# 8.8

# %%
import pandas as pd
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
df = pd.DataFrame(data)
print(df.iloc[1])
# Out:
# A    2
# B    5
# C    8
# Name: 1, dtype: int64

# %%
data = {'A': [1, 2], 'B': [3, 4]}
df = pd.DataFrame(data, index= ['row1', 'row2'])

print(df.loc['row1', 'B'])
# Out:
# 3

# %%
import pandas as pd
data = {'A': [10, 20, 30], 'B': [40, 50, 60]}
df = pd.DataFrame(data)

df = df.drop('B', axis=1)
print(df)
# Out:
#     A
# 0  10
# 1  20
# 2  30
